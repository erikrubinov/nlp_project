# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
data = pd.read_csv('../reports/run_without_ngrams_modified_pre_basic/classification_report_1.csv')

# %%
data
# Out:
#       Unnamed: 0  precision    recall  f1-score    support  \
# 0     CONSPIRACY   0.782288  0.768116  0.775137  276.00000
# 1       CRITICAL   0.879017  0.887405  0.883191  524.00000
# 2       accuracy   0.846250  0.846250  0.846250    0.84625
# 3      macro avg   0.830652  0.827760  0.829164  800.00000
# 4   weighted avg   0.845645  0.846250  0.845912  800.00000
# 5     CONSPIRACY   0.746835  0.855072  0.797297  276.00000
# 6       CRITICAL   0.917355  0.847328  0.880952  524.00000
# 7       accuracy   0.850000  0.850000  0.850000    0.85000
# 8      macro avg   0.832095  0.851200  0.839125  800.00000
# 9   weighted avg   0.858526  0.850000  0.852091  800.00000
# 10    CONSPIRACY   0.873239  0.673913  0.760736  276.00000
# 11      CRITICAL   0.846678  0.948473  0.894689  524.00000
# 12      accuracy   0.853750  0.853750  0.853750    0.85375
# 13     macro avg   0.859959  0.811193  0.827713  800.00000
# 14  weighted avg   0.855842  0.853750  0.848476  800.00000
# 15    CONSPIRACY   0.840000  0.684783  0.754491  276.00000
# 16      CRITICAL   0.848696  0.931298  0.888080  524.00000
# 17      accuracy   0.846250  0.846250  0.846250    0.84625
# 18     macro avg   0.844348  0.808040  0.821286  800.00000
# 19  weighted avg   0.845696  0.846250  0.841992  800.00000
# 20    CONSPIRACY   0.761745  0.822464  0.790941  276.00000
# 21      CRITICAL   0.902390  0.864504  0.883041  524.00000
# 22      accuracy   0.850000  0.850000  0.850000    0.85000
# 23     macro avg   0.832068  0.843484  0.836991  800.00000
# 24  weighted avg   0.853868  0.850000  0.851266  800.00000
# 25    CONSPIRACY   0.689655  0.869565  0.769231  276.00000
# 26      CRITICAL   0.920354  0.793893  0.852459  524.00000
# 27      accuracy   0.820000  0.820000  0.820000    0.82000
# 28     macro avg   0.805005  0.831729  0.810845  800.00000
# 29  weighted avg   0.840763  0.820000  0.823745  800.00000
# 30    CONSPIRACY   0.869369  0.699275  0.775100  276.00000
# 31      CRITICAL   0.856401  0.944656  0.898367  524.00000
# 32      accuracy   0.860000  0.860000  0.860000    0.86000
# 33     macro avg   0.862885  0.821966  0.836734  800.00000
# 34  weighted avg   0.860875  0.860000  0.855840  800.00000
# 35    CONSPIRACY   0.862832  0.706522  0.776892  276.00000
# 36      CRITICAL   0.858885  0.940840  0.897996  524.00000
# 37      accuracy   0.860000  0.860000  0.860000    0.86000
# 38     macro avg   0.860858  0.823681  0.837444  800.00000
# 39  weighted avg   0.860247  0.860000  0.856216  800.00000
#
#                                              pipeline     classifier  \
# 0   CountVectorizer with preprocessing function pr...  MultinomialNB
# 1   CountVectorizer with preprocessing function pr...  MultinomialNB
# 2   CountVectorizer with preprocessing function pr...  MultinomialNB
# 3   CountVectorizer with preprocessing function pr...  MultinomialNB
# 4   CountVectorizer with preprocessing function pr...  MultinomialNB
# 5   TfidfVectorizer with preprocessing function pr...  MultinomialNB
# 6   TfidfVectorizer with preprocessing function pr...  MultinomialNB
# 7   TfidfVectorizer with preprocessing function pr...  MultinomialNB
# 8   TfidfVectorizer with preprocessing function pr...  MultinomialNB
# 9   TfidfVectorizer with preprocessing function pr...  MultinomialNB
# 10  CountVectorizer with preprocessing function pr...  MLPClassifier
# 11  CountVectorizer with preprocessing function pr...  MLPClassifier
# 12  CountVectorizer with preprocessing function pr...  MLPClassifier
# 13  CountVectorizer with preprocessing function pr...  MLPClassifier
# 14  CountVectorizer with preprocessing function pr...  MLPClassifier
# 15  TfidfVectorizer with preprocessing function pr...  MLPClassifier
# 16  TfidfVectorizer with preprocessing function pr...  MLPClassifier
# 17  TfidfVectorizer with preprocessing function pr...  MLPClassifier
# 18  TfidfVectorizer with preprocessing function pr...  MLPClassifier
# 19  TfidfVectorizer with preprocessing function pr...  MLPClassifier
# 20  CountVectorizer with preprocessing function pr...  MultinomialNB
# 21  CountVectorizer with preprocessing function pr...  MultinomialNB
# 22  CountVectorizer with preprocessing function pr...  MultinomialNB
# 23  CountVectorizer with preprocessing function pr...  MultinomialNB
# 24  CountVectorizer with preprocessing function pr...  MultinomialNB
# 25  TfidfVectorizer with preprocessing function pr...  MultinomialNB
# 26  TfidfVectorizer with preprocessing function pr...  MultinomialNB
# 27  TfidfVectorizer with preprocessing function pr...  MultinomialNB
# 28  TfidfVectorizer with preprocessing function pr...  MultinomialNB
# 29  TfidfVectorizer with preprocessing function pr...  MultinomialNB
# 30  CountVectorizer with preprocessing function pr...  MLPClassifier
# 31  CountVectorizer with preprocessing function pr...  MLPClassifier
# 32  CountVectorizer with preprocessing function pr...  MLPClassifier
# 33  CountVectorizer with preprocessing function pr...  MLPClassifier
# 34  CountVectorizer with preprocessing function pr...  MLPClassifier
# 35  TfidfVectorizer with preprocessing function pr...  MLPClassifier
# 36  TfidfVectorizer with preprocessing function pr...  MLPClassifier
# 37  TfidfVectorizer with preprocessing function pr...  MLPClassifier
# 38  TfidfVectorizer with preprocessing function pr...  MLPClassifier
# 39  TfidfVectorizer with preprocessing function pr...  MLPClassifier
#
#          vectorizer  preprocess_function
# 0   CountVectorizer  preprocess_advanced
# 1   CountVectorizer  preprocess_advanced
# 2   CountVectorizer  preprocess_advanced
# 3   CountVectorizer  preprocess_advanced
# 4   CountVectorizer  preprocess_advanced
# 5   TfidfVectorizer  preprocess_advanced
# 6   TfidfVectorizer  preprocess_advanced
# 7   TfidfVectorizer  preprocess_advanced
# 8   TfidfVectorizer  preprocess_advanced
# 9   TfidfVectorizer  preprocess_advanced
# 10  CountVectorizer  preprocess_advanced
# 11  CountVectorizer  preprocess_advanced
# 12  CountVectorizer  preprocess_advanced
# 13  CountVectorizer  preprocess_advanced
# 14  CountVectorizer  preprocess_advanced
# 15  TfidfVectorizer  preprocess_advanced
# 16  TfidfVectorizer  preprocess_advanced
# 17  TfidfVectorizer  preprocess_advanced
# 18  TfidfVectorizer  preprocess_advanced
# 19  TfidfVectorizer  preprocess_advanced
# 20  CountVectorizer     preprocess_basic
# 21  CountVectorizer     preprocess_basic
# 22  CountVectorizer     preprocess_basic
# 23  CountVectorizer     preprocess_basic
# 24  CountVectorizer     preprocess_basic
# 25  TfidfVectorizer     preprocess_basic
# 26  TfidfVectorizer     preprocess_basic
# 27  TfidfVectorizer     preprocess_basic
# 28  TfidfVectorizer     preprocess_basic
# 29  TfidfVectorizer     preprocess_basic
# 30  CountVectorizer     preprocess_basic
# 31  CountVectorizer     preprocess_basic
# 32  CountVectorizer     preprocess_basic
# 33  CountVectorizer     preprocess_basic
# 34  CountVectorizer     preprocess_basic
# 35  TfidfVectorizer     preprocess_basic
# 36  TfidfVectorizer     preprocess_basic
# 37  TfidfVectorizer     preprocess_basic
# 38  TfidfVectorizer     preprocess_basic
# 39  TfidfVectorizer     preprocess_basic

# %%
# rename first column
data.rename(columns={'Unnamed: 0': 'type'}, inplace=True)

# %%
data
# Out:
#             type  precision    recall  f1-score    support  \
# 0     CONSPIRACY   0.782288  0.768116  0.775137  276.00000
# 1       CRITICAL   0.879017  0.887405  0.883191  524.00000
# 2       accuracy   0.846250  0.846250  0.846250    0.84625
# 3      macro avg   0.830652  0.827760  0.829164  800.00000
# 4   weighted avg   0.845645  0.846250  0.845912  800.00000
# 5     CONSPIRACY   0.746835  0.855072  0.797297  276.00000
# 6       CRITICAL   0.917355  0.847328  0.880952  524.00000
# 7       accuracy   0.850000  0.850000  0.850000    0.85000
# 8      macro avg   0.832095  0.851200  0.839125  800.00000
# 9   weighted avg   0.858526  0.850000  0.852091  800.00000
# 10    CONSPIRACY   0.873239  0.673913  0.760736  276.00000
# 11      CRITICAL   0.846678  0.948473  0.894689  524.00000
# 12      accuracy   0.853750  0.853750  0.853750    0.85375
# 13     macro avg   0.859959  0.811193  0.827713  800.00000
# 14  weighted avg   0.855842  0.853750  0.848476  800.00000
# 15    CONSPIRACY   0.840000  0.684783  0.754491  276.00000
# 16      CRITICAL   0.848696  0.931298  0.888080  524.00000
# 17      accuracy   0.846250  0.846250  0.846250    0.84625
# 18     macro avg   0.844348  0.808040  0.821286  800.00000
# 19  weighted avg   0.845696  0.846250  0.841992  800.00000
# 20    CONSPIRACY   0.761745  0.822464  0.790941  276.00000
# 21      CRITICAL   0.902390  0.864504  0.883041  524.00000
# 22      accuracy   0.850000  0.850000  0.850000    0.85000
# 23     macro avg   0.832068  0.843484  0.836991  800.00000
# 24  weighted avg   0.853868  0.850000  0.851266  800.00000
# 25    CONSPIRACY   0.689655  0.869565  0.769231  276.00000
# 26      CRITICAL   0.920354  0.793893  0.852459  524.00000
# 27      accuracy   0.820000  0.820000  0.820000    0.82000
# 28     macro avg   0.805005  0.831729  0.810845  800.00000
# 29  weighted avg   0.840763  0.820000  0.823745  800.00000
# 30    CONSPIRACY   0.869369  0.699275  0.775100  276.00000
# 31      CRITICAL   0.856401  0.944656  0.898367  524.00000
# 32      accuracy   0.860000  0.860000  0.860000    0.86000
# 33     macro avg   0.862885  0.821966  0.836734  800.00000
# 34  weighted avg   0.860875  0.860000  0.855840  800.00000
# 35    CONSPIRACY   0.862832  0.706522  0.776892  276.00000
# 36      CRITICAL   0.858885  0.940840  0.897996  524.00000
# 37      accuracy   0.860000  0.860000  0.860000    0.86000
# 38     macro avg   0.860858  0.823681  0.837444  800.00000
# 39  weighted avg   0.860247  0.860000  0.856216  800.00000
#
#                                              pipeline     classifier  \
# 0   CountVectorizer with preprocessing function pr...  MultinomialNB
# 1   CountVectorizer with preprocessing function pr...  MultinomialNB
# 2   CountVectorizer with preprocessing function pr...  MultinomialNB
# 3   CountVectorizer with preprocessing function pr...  MultinomialNB
# 4   CountVectorizer with preprocessing function pr...  MultinomialNB
# 5   TfidfVectorizer with preprocessing function pr...  MultinomialNB
# 6   TfidfVectorizer with preprocessing function pr...  MultinomialNB
# 7   TfidfVectorizer with preprocessing function pr...  MultinomialNB
# 8   TfidfVectorizer with preprocessing function pr...  MultinomialNB
# 9   TfidfVectorizer with preprocessing function pr...  MultinomialNB
# 10  CountVectorizer with preprocessing function pr...  MLPClassifier
# 11  CountVectorizer with preprocessing function pr...  MLPClassifier
# 12  CountVectorizer with preprocessing function pr...  MLPClassifier
# 13  CountVectorizer with preprocessing function pr...  MLPClassifier
# 14  CountVectorizer with preprocessing function pr...  MLPClassifier
# 15  TfidfVectorizer with preprocessing function pr...  MLPClassifier
# 16  TfidfVectorizer with preprocessing function pr...  MLPClassifier
# 17  TfidfVectorizer with preprocessing function pr...  MLPClassifier
# 18  TfidfVectorizer with preprocessing function pr...  MLPClassifier
# 19  TfidfVectorizer with preprocessing function pr...  MLPClassifier
# 20  CountVectorizer with preprocessing function pr...  MultinomialNB
# 21  CountVectorizer with preprocessing function pr...  MultinomialNB
# 22  CountVectorizer with preprocessing function pr...  MultinomialNB
# 23  CountVectorizer with preprocessing function pr...  MultinomialNB
# 24  CountVectorizer with preprocessing function pr...  MultinomialNB
# 25  TfidfVectorizer with preprocessing function pr...  MultinomialNB
# 26  TfidfVectorizer with preprocessing function pr...  MultinomialNB
# 27  TfidfVectorizer with preprocessing function pr...  MultinomialNB
# 28  TfidfVectorizer with preprocessing function pr...  MultinomialNB
# 29  TfidfVectorizer with preprocessing function pr...  MultinomialNB
# 30  CountVectorizer with preprocessing function pr...  MLPClassifier
# 31  CountVectorizer with preprocessing function pr...  MLPClassifier
# 32  CountVectorizer with preprocessing function pr...  MLPClassifier
# 33  CountVectorizer with preprocessing function pr...  MLPClassifier
# 34  CountVectorizer with preprocessing function pr...  MLPClassifier
# 35  TfidfVectorizer with preprocessing function pr...  MLPClassifier
# 36  TfidfVectorizer with preprocessing function pr...  MLPClassifier
# 37  TfidfVectorizer with preprocessing function pr...  MLPClassifier
# 38  TfidfVectorizer with preprocessing function pr...  MLPClassifier
# 39  TfidfVectorizer with preprocessing function pr...  MLPClassifier
#
#          vectorizer  preprocess_function
# 0   CountVectorizer  preprocess_advanced
# 1   CountVectorizer  preprocess_advanced
# 2   CountVectorizer  preprocess_advanced
# 3   CountVectorizer  preprocess_advanced
# 4   CountVectorizer  preprocess_advanced
# 5   TfidfVectorizer  preprocess_advanced
# 6   TfidfVectorizer  preprocess_advanced
# 7   TfidfVectorizer  preprocess_advanced
# 8   TfidfVectorizer  preprocess_advanced
# 9   TfidfVectorizer  preprocess_advanced
# 10  CountVectorizer  preprocess_advanced
# 11  CountVectorizer  preprocess_advanced
# 12  CountVectorizer  preprocess_advanced
# 13  CountVectorizer  preprocess_advanced
# 14  CountVectorizer  preprocess_advanced
# 15  TfidfVectorizer  preprocess_advanced
# 16  TfidfVectorizer  preprocess_advanced
# 17  TfidfVectorizer  preprocess_advanced
# 18  TfidfVectorizer  preprocess_advanced
# 19  TfidfVectorizer  preprocess_advanced
# 20  CountVectorizer     preprocess_basic
# 21  CountVectorizer     preprocess_basic
# 22  CountVectorizer     preprocess_basic
# 23  CountVectorizer     preprocess_basic
# 24  CountVectorizer     preprocess_basic
# 25  TfidfVectorizer     preprocess_basic
# 26  TfidfVectorizer     preprocess_basic
# 27  TfidfVectorizer     preprocess_basic
# 28  TfidfVectorizer     preprocess_basic
# 29  TfidfVectorizer     preprocess_basic
# 30  CountVectorizer     preprocess_basic
# 31  CountVectorizer     preprocess_basic
# 32  CountVectorizer     preprocess_basic
# 33  CountVectorizer     preprocess_basic
# 34  CountVectorizer     preprocess_basic
# 35  TfidfVectorizer     preprocess_basic
# 36  TfidfVectorizer     preprocess_basic
# 37  TfidfVectorizer     preprocess_basic
# 38  TfidfVectorizer     preprocess_basic
# 39  TfidfVectorizer     preprocess_basic

# %%
# remove all where type not "weighted avg"
data = data[data['type'] == 'weighted avg']
data
# Out:
#             type  precision   recall  f1-score  support  \
# 4   weighted avg   0.845645  0.84625  0.845912    800.0
# 9   weighted avg   0.858526  0.85000  0.852091    800.0
# 14  weighted avg   0.855842  0.85375  0.848476    800.0
# 19  weighted avg   0.845696  0.84625  0.841992    800.0
# 24  weighted avg   0.853868  0.85000  0.851266    800.0
# 29  weighted avg   0.840763  0.82000  0.823745    800.0
# 34  weighted avg   0.860875  0.86000  0.855840    800.0
# 39  weighted avg   0.860247  0.86000  0.856216    800.0
#
#                                              pipeline     classifier  \
# 4   CountVectorizer with preprocessing function pr...  MultinomialNB
# 9   TfidfVectorizer with preprocessing function pr...  MultinomialNB
# 14  CountVectorizer with preprocessing function pr...  MLPClassifier
# 19  TfidfVectorizer with preprocessing function pr...  MLPClassifier
# 24  CountVectorizer with preprocessing function pr...  MultinomialNB
# 29  TfidfVectorizer with preprocessing function pr...  MultinomialNB
# 34  CountVectorizer with preprocessing function pr...  MLPClassifier
# 39  TfidfVectorizer with preprocessing function pr...  MLPClassifier
#
#          vectorizer  preprocess_function
# 4   CountVectorizer  preprocess_advanced
# 9   TfidfVectorizer  preprocess_advanced
# 14  CountVectorizer  preprocess_advanced
# 19  TfidfVectorizer  preprocess_advanced
# 24  CountVectorizer     preprocess_basic
# 29  TfidfVectorizer     preprocess_basic
# 34  CountVectorizer     preprocess_basic
# 39  TfidfVectorizer     preprocess_basic

# %%
sns.barplot(x='classifier', y='f1-score', hue="preprocess_function", data=data)
# Out:
# <Axes: xlabel='classifier', ylabel='f1-score'>

# %%
sns.barplot(x='vectorizer', y='f1-score', hue="preprocess_function", data=data)
# Out:
# <Axes: xlabel='vectorizer', ylabel='f1-score'>

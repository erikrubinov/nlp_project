# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
data = pd.read_csv('../reports/classification_report_1.csv')

# %%
data
# Out:
#        Unnamed: 0  precision    recall  f1-score    support  \
# 0      CONSPIRACY   0.782288  0.768116  0.775137  276.00000
# 1        CRITICAL   0.879017  0.887405  0.883191  524.00000
# 2        accuracy   0.846250  0.846250  0.846250    0.84625
# 3       macro avg   0.830652  0.827760  0.829164  800.00000
# 4    weighted avg   0.845645  0.846250  0.845912  800.00000
# ..            ...        ...       ...       ...        ...
# 115    CONSPIRACY   0.862637  0.568841  0.685590  276.00000
# 116      CRITICAL   0.807443  0.952290  0.873905  524.00000
# 117      accuracy   0.820000  0.820000  0.820000    0.82000
# 118     macro avg   0.835040  0.760565  0.779747  800.00000
# 119  weighted avg   0.826485  0.820000  0.808936  800.00000
#
#                                               pipeline     classifier  \
# 0    CountVectorizer with preprocessing function pr...  MultinomialNB
# 1    CountVectorizer with preprocessing function pr...  MultinomialNB
# ...

# %%
# rename first column
data.rename(columns={'Unnamed: 0': 'type'}, inplace=True)

# %%
data
# Out:
#              type  precision    recall  f1-score    support  \
# 0      CONSPIRACY   0.782288  0.768116  0.775137  276.00000
# 1        CRITICAL   0.879017  0.887405  0.883191  524.00000
# 2        accuracy   0.846250  0.846250  0.846250    0.84625
# 3       macro avg   0.830652  0.827760  0.829164  800.00000
# 4    weighted avg   0.845645  0.846250  0.845912  800.00000
# ..            ...        ...       ...       ...        ...
# 115    CONSPIRACY   0.862637  0.568841  0.685590  276.00000
# 116      CRITICAL   0.807443  0.952290  0.873905  524.00000
# 117      accuracy   0.820000  0.820000  0.820000    0.82000
# 118     macro avg   0.835040  0.760565  0.779747  800.00000
# 119  weighted avg   0.826485  0.820000  0.808936  800.00000
#
#                                               pipeline     classifier  \
# 0    CountVectorizer with preprocessing function pr...  MultinomialNB
# 1    CountVectorizer with preprocessing function pr...  MultinomialNB
# ...

# %%
# remove all where type not "weighted avg"
data = data[data['type'] == 'weighted avg']
data
# Out:
#              type  precision   recall  f1-score  support  \
# 4    weighted avg   0.845645  0.84625  0.845912    800.0
# 9    weighted avg   0.858526  0.85000  0.852091    800.0
# 14   weighted avg   0.846234  0.84375  0.844682    800.0
# 19   weighted avg   0.848374  0.82375  0.827645    800.0
# 24   weighted avg   0.817456  0.82000  0.817924    800.0
# 29   weighted avg   0.827902  0.82500  0.826108    800.0
# 34   weighted avg   0.854692  0.85250  0.847072    800.0
# 39   weighted avg   0.844484  0.84500  0.840604    800.0
# 44   weighted avg   0.833500  0.82125  0.808040    800.0
# 49   weighted avg   0.851251  0.84875  0.842847    800.0
# 54   weighted avg   0.804969  0.79500  0.777944    800.0
# 59   weighted avg   0.793467  0.78875  0.773138    800.0
# 64   weighted avg   0.845566  0.84500  0.845261    800.0
# 69   weighted avg   0.842406  0.82125  0.824997    800.0
# 74   weighted avg   0.858882  0.85125  0.853200    800.0
# ...

# %%
sns.barplot(x='classifier', y='f1-score', hue="preprocess_function", data=data)
# Out:
# <Axes: xlabel='classifier', ylabel='f1-score'>

# %%
sns.barplot(x='vectorizer', y='f1-score', hue="preprocess_function", data=data)
# Out:
# <Axes: xlabel='vectorizer', ylabel='f1-score'>

# %%
# merge ngram_lower_bound and ngram_upper_bound into one column
data['ngram_lower_bound'] = data['ngram_lower_bound'].astype(str)
data['ngram_upper_bound'] = data['ngram_upper_bound'].astype(str)
data['ngram'] = data['ngram_lower_bound'] + '-' + data['ngram_upper_bound']
sns.barplot(x='ngram', y='f1-score', hue="preprocess_function", data=data)
plt.xlabel('Ngram range')
plt.ylabel('Average F1-Score')
plt.title('average F1-Scores for the different n-gram ranges per pre-processing function')
# save fig
plt.savefig("../reports/figures/01/why_ngram_do_not_work.png")
plt.show()
# Out:
# /tmp/ipykernel_15787/3160901966.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ngram_lower_bound'] = data['ngram_lower_bound'].astype(str)
# /tmp/ipykernel_15787/3160901966.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ngram_upper_bound'] = data['ngram_upper_bound'].astype(str)
# /tmp/ipykernel_15787/3160901966.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fnn_misclassifications = pd.read_csv('../reports/misclassified_fnn.csv')
nb_misclassifications = pd.read_csv('../reports/misclassified_nb.csv')

# %%
fnn_misclassifications
# Out:
#      Unnamed: 0                                               text  \
# 0          1230  DOCTOR ADMITS ONCE HE INTUBATES PATIENTS 99 % ...
# 1          3934  The Ten Stages of Genocide - Happening as we s...
# 2          3121  The Federalist article on controlled voluntary...
# 3          1813  “ A public official acting in contravention of...
# 4          3770  We have been warning about ...   Vaccine manda...
# ..          ...                                                ...
# 106        2944  Part of the reason we will never see the media...
# 107        3628  For a long time all vaccines contained toxic a...
# 108        3638  A private owned vaccine sales company that own...
# 109        1923  " British State Deployed Counter - Terrorism U...
# 110         502  Who else finds it awfully peculiar that the US...
#
#        category comment_length uppercase_amount predicted_category
# 0      CRITICAL           long          neutral         CONSPIRACY
# ...

# %%
nb_misclassifications
# Out:
#      Unnamed: 0                                               text  \
# 0          1453  Maher : ' Liberal Media ' Must Take ' Responsi...
# 1          2084  # AlexJonesShow LIVE : Medical Expert Exposes ...
# 2          3121  The Federalist article on controlled voluntary...
# 3          1813  “ A public official acting in contravention of...
# 4           843  Absolutely everything , from breathing too muc...
# ..          ...                                                ...
# 115        3722  President Trump did a great job expediting Ope...
# 116        3638  A private owned vaccine sales company that own...
# 117        2002  Incredibly compelling , science - based , sane...
# 118        1923  " British State Deployed Counter - Terrorism U...
# 119         502  Who else finds it awfully peculiar that the US...
#
#        category comment_length uppercase_amount predicted_category
# 0      CRITICAL          short             high         CONSPIRACY
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
data = pd.read_csv('../reports/classification_report_2.csv')

# %%
data
# Out:
#        Unnamed: 0  precision    recall  f1-score  support  \
# 0      CONSPIRACY   0.862637  0.568841  0.685590   276.00
# 1        CRITICAL   0.807443  0.952290  0.873905   524.00
# 2        accuracy   0.820000  0.820000  0.820000     0.82
# 3       macro avg   0.835040  0.760565  0.779747   800.00
# 4    weighted avg   0.826485  0.820000  0.808936   800.00
# ..            ...        ...       ...       ...      ...
# 715    CONSPIRACY   0.862637  0.568841  0.685590   276.00
# 716      CRITICAL   0.807443  0.952290  0.873905   524.00
# 717      accuracy   0.820000  0.820000  0.820000     0.82
# 718     macro avg   0.835040  0.760565  0.779747   800.00
# 719  weighted avg   0.826485  0.820000  0.808936   800.00
#
#                                               pipeline     classifier  \
# 0    CountVectorizer with preprocessing function pr...  MultinomialNB
# 1    CountVectorizer with preprocessing function pr...  MultinomialNB
# 2    CountVectorizer with preprocessing function pr...  MultinomialNB
# 3    CountVectorizer with preprocessing function pr...  MultinomialNB
# 4    CountVectorizer with preprocessing function pr...  MultinomialNB
# ..                                                 ...            ...
# 715  TfidfVectorizer with preprocessing function pr...  MLPClassifier
# 716  TfidfVectorizer with preprocessing function pr...  MLPClassifier
# 717  TfidfVectorizer with preprocessing function pr...  MLPClassifier
# 718  TfidfVectorizer with preprocessing function pr...  MLPClassifier
# 719  TfidfVectorizer with preprocessing function pr...  MLPClassifier
#
#                               vectorizer  ngram_lower_bound  \
# 0                      CountVectorizer()                  1
# 1                      CountVectorizer()                  1
# 2                      CountVectorizer()                  1
# 3                      CountVectorizer()                  1
# 4                      CountVectorizer()                  1
# ..                                   ...                ...
# 715  TfidfVectorizer(ngram_range=(2, 2))                  2
# 716  TfidfVectorizer(ngram_range=(2, 2))                  2
# 717  TfidfVectorizer(ngram_range=(2, 2))                  2
# 718  TfidfVectorizer(ngram_range=(2, 2))                  2
# 719  TfidfVectorizer(ngram_range=(2, 2))                  2
#
#      ngram_upper_bound  preprocess_function          features  \
# 0                    1  preprocess_advanced  CombinedFeatures
# 1                    1  preprocess_advanced  CombinedFeatures
# 2                    1  preprocess_advanced  CombinedFeatures
# 3                    1  preprocess_advanced  CombinedFeatures
# 4                    1  preprocess_advanced  CombinedFeatures
# ..                 ...                  ...               ...
# 715                  2     preprocess_basic  CombinedFeatures
# 716                  2     preprocess_basic  CombinedFeatures
# 717                  2     preprocess_basic  CombinedFeatures
# 718                  2     preprocess_basic  CombinedFeatures
# 719                  2     preprocess_basic  CombinedFeatures
#
#      preprocess_function_uses_lemmatization  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
# ..                                      ...
# 715                                    True
# 716                                    True
# 717                                    True
# 718                                    True
# 719                                    True
#
#      preprocess_function_uses_stemmanization  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
# ..                                       ...
# 715                                     True
# 716                                     True
# 717                                     True
# 718                                     True
# 719                                     True
#
#                                feature_list
# 0    ["uppercase_amount", "comment_length"]
# 1    ["uppercase_amount", "comment_length"]
# 2    ["uppercase_amount", "comment_length"]
# 3    ["uppercase_amount", "comment_length"]
# 4    ["uppercase_amount", "comment_length"]
# ..                                      ...
# 715                    ["uppercase_amount"]
# 716                    ["uppercase_amount"]
# 717                    ["uppercase_amount"]
# 718                    ["uppercase_amount"]
# 719                    ["uppercase_amount"]
#
# [720 rows x 15 columns]

# %%
# rename first column
data.rename(columns={'Unnamed: 0': 'type'}, inplace=True)

# %%
data
# Out:
#              type  precision    recall  f1-score  support  \
# 0      CONSPIRACY   0.862637  0.568841  0.685590   276.00
# 1        CRITICAL   0.807443  0.952290  0.873905   524.00
# 2        accuracy   0.820000  0.820000  0.820000     0.82
# 3       macro avg   0.835040  0.760565  0.779747   800.00
# 4    weighted avg   0.826485  0.820000  0.808936   800.00
# ..            ...        ...       ...       ...      ...
# 715    CONSPIRACY   0.862637  0.568841  0.685590   276.00
# 716      CRITICAL   0.807443  0.952290  0.873905   524.00
# 717      accuracy   0.820000  0.820000  0.820000     0.82
# 718     macro avg   0.835040  0.760565  0.779747   800.00
# 719  weighted avg   0.826485  0.820000  0.808936   800.00
#
#                                               pipeline     classifier  \
# 0    CountVectorizer with preprocessing function pr...  MultinomialNB
# 1    CountVectorizer with preprocessing function pr...  MultinomialNB
# 2    CountVectorizer with preprocessing function pr...  MultinomialNB
# 3    CountVectorizer with preprocessing function pr...  MultinomialNB
# 4    CountVectorizer with preprocessing function pr...  MultinomialNB
# ..                                                 ...            ...
# 715  TfidfVectorizer with preprocessing function pr...  MLPClassifier
# 716  TfidfVectorizer with preprocessing function pr...  MLPClassifier
# 717  TfidfVectorizer with preprocessing function pr...  MLPClassifier
# 718  TfidfVectorizer with preprocessing function pr...  MLPClassifier
# 719  TfidfVectorizer with preprocessing function pr...  MLPClassifier
#
#                               vectorizer  ngram_lower_bound  \
# 0                      CountVectorizer()                  1
# 1                      CountVectorizer()                  1
# 2                      CountVectorizer()                  1
# 3                      CountVectorizer()                  1
# 4                      CountVectorizer()                  1
# ..                                   ...                ...
# 715  TfidfVectorizer(ngram_range=(2, 2))                  2
# 716  TfidfVectorizer(ngram_range=(2, 2))                  2
# 717  TfidfVectorizer(ngram_range=(2, 2))                  2
# 718  TfidfVectorizer(ngram_range=(2, 2))                  2
# 719  TfidfVectorizer(ngram_range=(2, 2))                  2
#
#      ngram_upper_bound  preprocess_function          features  \
# 0                    1  preprocess_advanced  CombinedFeatures
# 1                    1  preprocess_advanced  CombinedFeatures
# 2                    1  preprocess_advanced  CombinedFeatures
# 3                    1  preprocess_advanced  CombinedFeatures
# 4                    1  preprocess_advanced  CombinedFeatures
# ..                 ...                  ...               ...
# 715                  2     preprocess_basic  CombinedFeatures
# 716                  2     preprocess_basic  CombinedFeatures
# 717                  2     preprocess_basic  CombinedFeatures
# 718                  2     preprocess_basic  CombinedFeatures
# 719                  2     preprocess_basic  CombinedFeatures
#
#      preprocess_function_uses_lemmatization  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
# ..                                      ...
# 715                                    True
# 716                                    True
# 717                                    True
# 718                                    True
# 719                                    True
#
#      preprocess_function_uses_stemmanization  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
# ..                                       ...
# 715                                     True
# 716                                     True
# 717                                     True
# 718                                     True
# 719                                     True
#
#                                feature_list
# 0    ["uppercase_amount", "comment_length"]
# 1    ["uppercase_amount", "comment_length"]
# 2    ["uppercase_amount", "comment_length"]
# 3    ["uppercase_amount", "comment_length"]
# 4    ["uppercase_amount", "comment_length"]
# ..                                      ...
# 715                    ["uppercase_amount"]
# 716                    ["uppercase_amount"]
# 717                    ["uppercase_amount"]
# 718                    ["uppercase_amount"]
# 719                    ["uppercase_amount"]
#
# [720 rows x 15 columns]

# %%
# remove all where type not "weighted avg"
data = data[data['type'] == 'weighted avg']
data
# Out:
#              type  precision  recall  f1-score  support  \
# 4    weighted avg   0.826485    0.82  0.808936    800.0
# 9    weighted avg   0.826485    0.82  0.808936    800.0
# 14   weighted avg   0.826485    0.82  0.808936    800.0
# 19   weighted avg   0.826485    0.82  0.808936    800.0
# 24   weighted avg   0.826485    0.82  0.808936    800.0
# ..            ...        ...     ...       ...      ...
# 699  weighted avg   0.826485    0.82  0.808936    800.0
# 704  weighted avg   0.826485    0.82  0.808936    800.0
# 709  weighted avg   0.826485    0.82  0.808936    800.0
# 714  weighted avg   0.826485    0.82  0.808936    800.0
# 719  weighted avg   0.826485    0.82  0.808936    800.0
#
#                                               pipeline     classifier  \
# 4    CountVectorizer with preprocessing function pr...  MultinomialNB
# 9    TfidfVectorizer with preprocessing function pr...  MultinomialNB
# 14   CountVectorizer with preprocessing function pr...  MultinomialNB
# 19   TfidfVectorizer with preprocessing function pr...  MultinomialNB
# 24   CountVectorizer with preprocessing function pr...  MultinomialNB
# ..                                                 ...            ...
# 699  TfidfVectorizer with preprocessing function pr...  MLPClassifier
# 704  CountVectorizer with preprocessing function pr...  MLPClassifier
# 709  TfidfVectorizer with preprocessing function pr...  MLPClassifier
# 714  CountVectorizer with preprocessing function pr...  MLPClassifier
# 719  TfidfVectorizer with preprocessing function pr...  MLPClassifier
#
#                               vectorizer  ngram_lower_bound  \
# 4                      CountVectorizer()                  1
# 9                      TfidfVectorizer()                  1
# 14                     CountVectorizer()                  1
# 19                     TfidfVectorizer()                  1
# 24   CountVectorizer(ngram_range=(1, 2))                  1
# ..                                   ...                ...
# 699  TfidfVectorizer(ngram_range=(1, 2))                  1
# 704  CountVectorizer(ngram_range=(2, 2))                  2
# 709  TfidfVectorizer(ngram_range=(2, 2))                  2
# 714  CountVectorizer(ngram_range=(2, 2))                  2
# 719  TfidfVectorizer(ngram_range=(2, 2))                  2
#
#      ngram_upper_bound  preprocess_function          features  \
# 4                    1  preprocess_advanced  CombinedFeatures
# 9                    1  preprocess_advanced  CombinedFeatures
# 14                   1  preprocess_advanced  CombinedFeatures
# 19                   1  preprocess_advanced  CombinedFeatures
# 24                   2  preprocess_advanced  CombinedFeatures
# ..                 ...                  ...               ...
# 699                  2     preprocess_basic  CombinedFeatures
# 704                  2     preprocess_basic  CombinedFeatures
# 709                  2     preprocess_basic  CombinedFeatures
# 714                  2     preprocess_basic  CombinedFeatures
# 719                  2     preprocess_basic  CombinedFeatures
#
#      preprocess_function_uses_lemmatization  \
# 4                                     False
# 9                                     False
# 14                                     True
# 19                                     True
# 24                                    False
# ..                                      ...
# 699                                    True
# 704                                   False
# 709                                   False
# 714                                    True
# 719                                    True
#
#      preprocess_function_uses_stemmanization  \
# 4                                      False
# 9                                      False
# 14                                      True
# 19                                      True
# 24                                     False
# ..                                       ...
# 699                                     True
# 704                                    False
# 709                                    False
# 714                                     True
# 719                                     True
#
#                                feature_list
# 4    ["uppercase_amount", "comment_length"]
# 9    ["uppercase_amount", "comment_length"]
# 14   ["uppercase_amount", "comment_length"]
# 19   ["uppercase_amount", "comment_length"]
# 24   ["uppercase_amount", "comment_length"]
# ..                                      ...
# 699                    ["uppercase_amount"]
# 704                    ["uppercase_amount"]
# 709                    ["uppercase_amount"]
# 714                    ["uppercase_amount"]
# 719                    ["uppercase_amount"]
#
# [144 rows x 15 columns]

# %%
sns.barplot(x='classifier', y='f1-score', hue="preprocess_function", data=data)
# Out:
# <Axes: xlabel='classifier', ylabel='f1-score'>

# %%
sns.barplot(x='vectorizer', y='f1-score', hue="preprocess_function", data=data)
# rotate x-axis labels
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3, 4, 5],
#  [Text(0, 0, 'CountVectorizer()'),
#   Text(1, 0, 'TfidfVectorizer()'),
#   Text(2, 0, 'CountVectorizer(ngram_range=(1, 2))'),
#   Text(3, 0, 'TfidfVectorizer(ngram_range=(1, 2))'),
#   Text(4, 0, 'CountVectorizer(ngram_range=(2, 2))'),
#   Text(5, 0, 'TfidfVectorizer(ngram_range=(2, 2))')])

# %%
# merge ngram_lower_bound and ngram_upper_bound into one column
data['ngram_lower_bound'] = data['ngram_lower_bound'].astype(str)
data['ngram_upper_bound'] = data['ngram_upper_bound'].astype(str)
data['ngram'] = data['ngram_lower_bound'] + '-' + data['ngram_upper_bound']
sns.barplot(x='ngram', y='f1-score', hue="preprocess_function", data=data)
# Out:
# /tmp/ipykernel_20012/494262278.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ngram_lower_bound'] = data['ngram_lower_bound'].astype(str)
# /tmp/ipykernel_20012/494262278.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ngram_upper_bound'] = data['ngram_upper_bound'].astype(str)
# /tmp/ipykernel_20012/494262278.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ngram'] = data['ngram_lower_bound'] + '-' + data['ngram_upper_bound']
# <Axes: xlabel='ngram', ylabel='f1-score'>
